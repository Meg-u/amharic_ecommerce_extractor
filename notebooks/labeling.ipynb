# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, clear_output
import re

# CONFIG 
CSV_PATH = '../data/zemenexpress/messages_cleaned.csv'
SAVE_PATH = '../data/conll_dataset.txt'
NUM_TO_LABEL = 30

# %%
df = pd.read_csv(CSV_PATH, encoding='utf-8', dtype=str)

# Show a few columns side by side if available
print(df.head(5).to_string())
# Out:
#          channel message_id                 date       sender_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text has_media                        media_file                                                                                           clean_text
# 0  @ZemenExpress       6985  2025-06-21 05:42:46  -1001307493052                                                  💥💥...................................💥💥\n\n📌1 pairs Sneaker Crease Protector\n\nዋጋ፦  💵🏷 400 ብር\n\n♦️ውስን ፍሬ ነው ያለው🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍♦️#መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ. S05/S06\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥      True  data/zemenexpress/media/6985.jpg                                   ዋጋ፦ ብር ውስን ፍሬ ነው ያለው አድራሻ ቢሮ ቁ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 1  @ZemenExpress       6984  2025-06-21 05:42:19  -1001307493052                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN      True  data/zemenexpress/media/6984.jpg                                                                                                  NaN
# 2  @ZemenExpress       6983  2025-06-21 05:42:19  -1001307493052                                                  💥💥...................................💥💥\n\n📌1 pairs Sneaker Crease Protector\n\nዋጋ፦  💵🏷 400 ብር\n\n♦️ውስን ፍሬ ነው ያለው🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍♦️#መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ. S05/S06\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥      True  data/zemenexpress/media/6983.jpg                                   ዋጋ፦ ብር ውስን ፍሬ ነው ያለው አድራሻ ቢሮ ቁ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 3  @ZemenExpress       6982  2025-06-18 06:01:10  -1001307493052  💥💥...................................💥💥\n\n📌Imitation Volcano Humidifier with LED Light\n\n👍በኤሌክትሪክ:የሚሰራ ለቤት መልካም መዓዛን የሚሰጥ\n\nዋጋ፦  💲🏷  1400 ብር\n\n📍ውስን ፍሬ ነው ያለን🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍♦️#መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ. S05/S06\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥     False                               NaN    በኤሌክትሪክየሚሰራ ለቤት መልካም መአዛን የሚሰጥ ዋጋ፦ ብር ውስን ፍሬ ነው ያለን አድራሻ ቢሮ ቁ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን
# 4  @ZemenExpress       6981  2025-06-16 12:21:00  -1001307493052                              💥💥...................................💥💥\n\n📌 Baby Carrier\n\n👍በፈለጉት አቅጣጫ ልጅዎን  በምቾት ማዘል ያስችልዎታል\n\nዋጋ፦  💲🏷  2400 ብር\n\n📍ውስን ፍሬ ነው ያለን🔥🔥🔥\n\n🏢 አድራሻ👉\n\n📍♦️#መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ. S05/S06\n\n\n     💧💧💧💧\n\n\n    📲 0902660722\n    📲 0928460606 \n\n🔖\n💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽\n\n@zemencallcenter \n\n@zemenexpressadmin\n\nለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️\nhttps://telegram.me/zemenexpress\n\n💥💥...................................💥💥     False                               NaN  በፈለጉት አቅጣጫ ልጅዎን በምቾት ማዘል ያስችልዎታል ዋጋ፦ ብር ውስን ፍሬ ነው ያለን አድራሻ ቢሮ ቁ በ ለማዘዝ ይጠቀሙ ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን

# %%
messages = df['text'].dropna().head(NUM_TO_LABEL).tolist()

# %%
label_options = ['O', 'B-Product', 'I-Product', 'B-PRICE', 'I-PRICE', 'B-LOC', 'I-LOC', 'B-CONTACT_INFO']
labeled_data = []

# %%
def custom_tokenize(text):
    text = text.replace('_', ' ')  # split compound tokens
    tokens = []

    # Keep Amharic (U+1200–137F), Latin (A-Za-z), digits, punctuation
    cleaned_text = re.sub(r'[^\u1200-\u137F\u0041-\u005A\u0061-\u007A0-9\s/@#:]', '', text)

    # Split on spaces and slashes
    rough_tokens = re.split(r'\s+|/', cleaned_text)

    # Remove empty tokens
    tokens = [tok for tok in rough_tokens if tok.strip()]

    return tokens

# %%
def label_message(index):
    #clear_output(wait=True)

    if index >= len(messages):
        with open(SAVE_PATH, 'a', encoding='utf-8') as f:
            for entry in labeled_data:
                for token, label in entry:
                    f.write(f"{token} {label}\n")
                f.write("\n")
        print(f"All done! Labeled {len(messages)} messages and saved to {SAVE_PATH}")
        return

    msg = messages[index]
    tokens = custom_tokenize(msg)

    print(f"\n📨 Message {index + 1} / {len(messages)}")
    print("Original Message:")
    print(msg)
    print("\n Start labeling:")

    dropdowns = []
    for token in tokens:
        label_dropdown = widgets.Dropdown(
            options=label_options,
            value='O',
            description=token,
            layout=widgets.Layout(width='auto'),
            style={'description_width': 'initial'}
        )
        dropdowns.append(label_dropdown)
        display(label_dropdown)

    # Make sure this function is defined right here
    def save_labels(_):
        entry = [(dropdown.description, dropdown.value) for dropdown in dropdowns]
        labeled_data.append(entry)
        label_message(index + 1)  # Recursive call to next message

    # Create and bind the button AFTER defining save_labels
    save_button = widgets.Button(description="Save & Next", button_style='success')
    save_button.on_click(save_labels)
    display(save_button)
label_message(11)
# Out:
# 📨 Message 12 / 30
# Original Message:
# 💥💥...................................💥💥
#
# 📌5-in-1 Trouser Hanger የሱሪ ማስቀመጫ
#
# ዋጋ፦  💲🏷  650 ብር
#
# 📍ውስን ፍሬ ነው ያለን🔥🔥🔥
#
# 🏢 አድራሻ👉
#
# 📍♦️#መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ. S05/S06
#
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
#
#  Start labeling:
# Dropdown(description='5in1', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='Trouser', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE'…
# Dropdown(description='Hanger', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE',…
# Dropdown(description='የሱሪ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='ማስቀመጫ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', …
# Dropdown(description='ዋጋ፦', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='650', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='ብር', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-…
# Dropdown(description='ውስን', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='ፍሬ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-…
# Dropdown(description='ነው', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-…
# Dropdown(description='ያለን', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='አድራሻ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='#መገናኛ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', …
# Dropdown(description='መሰረት', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='ደፋር', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='ሞል', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-…
# Dropdown(description='ሁለተኛ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='ፎቅ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-…
# Dropdown(description='ቢሮ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-…
# Dropdown(description='ቁ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I-P…
# Dropdown(description='S05', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='S06', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', 'I…
# Dropdown(description='0902660722', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRI…
# Dropdown(description='0928460606', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRI…
# Dropdown(description='በTelegram', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRIC…
# Dropdown(description='ለማዘዝ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='ይጠቀሙ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='@zemencallcenter', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', …
# Dropdown(description='@zemenexpressadmin', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product'…
# Dropdown(description='ለተጨማሪ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', …
# Dropdown(description='ማብራሪያ', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', …
# Dropdown(description='የቴሌግራም', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE',…
# Dropdown(description='ገፃችን', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE', '…
# Dropdown(description='https:', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRICE',…
# Dropdown(description='telegramme', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-PRI…
# Dropdown(description='zemenexpress', layout=Layout(width='auto'), options=('O', 'B-Product', 'I-Product', 'B-P…
# Button(button_style='success', description='Save & Next', style=ButtonStyle())

# %%
with open(SAVE_PATH, 'a', encoding='utf-8') as f:
    for entry in labeled_data:
        for token, label in entry:
            f.write(f"{token} {label}\n")
        f.write("\n")  # blank line between messages
